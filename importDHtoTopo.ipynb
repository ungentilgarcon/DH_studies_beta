# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

from topogram_client import TopogramAPIClient

from csv import DictReader
import os
import json
#import pymongo
#import musicbrainzngs
import arrow
from datetime import datetime
from pymongo import MongoClient
from collections import defaultdict
from dateutil import parser
from datetime import timedelta

# %%
def create_topogram(title, nodes, edges):

    print "Creating topogram '%s'"%title

    try :
        r = topogram.create_topogram(title)
    except ValueError:
        print '> Topogram already exists'
        r = topogram.get_topogram_by_name(title)
    print r
    topogram_ID = r["data"]["_id"]
    print "topogram ID : %s"%topogram_ID

    # get and backup existing nodes and edges
    existing_nodes = topogram.get_nodes(topogram_ID)["data"]
    existing_edges = topogram.get_edges(topogram_ID)["data"]

    # clear existing graph
    if len(existing_nodes):
        topogram.delete_nodes([n["_id"] for n in existing_nodes])
        print "%s nodes deleted"%len(existing_nodes)
    if len(existing_edges):
        topogram.delete_edges([n["_id"] for n in existing_edges])
        print "%s edges deleted"%len(existing_edges)

    r = topogram.create_nodes(topogram_ID, nodes)
    print r
    print "%s nodes created."%len(r["data"])
    r = topogram.create_edges(topogram_ID, edges)
    print "%s edges created."%len(r["data"])

    print "done. Topogram has been updated. Check it at %s/topograms/%s"%(TOPOGRAM_URL, topogram_ID)

# %%
import pickle
with open('dict_corrected_DH.obj', 'rb') as handle:
    dict_corrected_DH = pickle.load(handle)
with open('geocoded_locs.obj', 'rb') as handle:
    geocoded_locs = pickle.load(handle)

with open('corpus_mails_DH.obj', 'rb') as handle:
    corpus_mails_DH = pickle.load(handle)

with open('dict_noms_mails_debut_fin.obj', 'rb') as handle:
    dict_noms_mails_debut_fin = pickle.load(handle)
    

with open('liste_de_tous_les_mails.obj', 'rb') as handle:
    liste_de_tous_les_mails = pickle.load(handle)

# %%
    
print str(dict_corrected_DH)[:1000],"\n"
print str(geocoded_locs)[:1000],"\n"
print str(corpus_mails_DH)[:1000],"\n"
print str(dict_noms_mails_debut_fin)[:1000],"\n"
print str(liste_de_tous_les_mails)[:1000],"\n"
# Out:
# {'lecnam.net': {u'geometry': {u'location': {u'lat': 49.24403, u'lng': 4.0595627}, u'viewport': {u'northeast': {u'lat': 49.2453789802915, u'lng': 4.060911680291502}, u'southwest': {u'lat': 49.2426810197085, u'lng': 4.058213719708498}}, u'location_type': u'GEOMETRIC_CENTER'}, u'partial_match': True, u'place_id': u'ChIJ-6xk5S906UcR2dR69fjERJg', u'address_components': [{u'long_name': u'Rue des Cray\xe8res', u'types': [u'route'], u'short_name': u'Rue des Cray\xe8res'}, {u'long_name': u'Reims', u'types': [u'locality', u'political'], u'short_name': u'Reims'}, {u'long_name': u'Marne', u'types': [u'administrative_area_level_2', u'political'], u'short_name': u'Marne'}, {u'long_name': u'Grand Est', u'types': [u'administrative_area_level_1', u'political'], u'short_name': u'Grand Est'}, {u'long_name': u'France', u'types': [u'country', u'political'], u'short_name': u'FR'}, {u'long_name': u'51687', u'types': [u'postal_code'], u'short_name': u'51687'}], u'formatted_address': u'Rue des Cray\xe8res, 516
#
# {'lecnam.net': {u'geometry': {u'location': {u'lat': 49.24403, u'lng': 4.0595627}, u'viewport': {u'northeast': {u'lat': 49.2453789802915, u'lng': 4.060911680291502}, u'southwest': {u'lat': 49.2426810197085, u'lng': 4.058213719708498}}, u'location_type': u'GEOMETRIC_CENTER'}, u'partial_match': True, u'place_id': u'ChIJ-6xk5S906UcR2dR69fjERJg', u'address_components': [{u'long_name': u'Rue des Cray\xe8res', u'short_name': u'Rue des Cray\xe8res', u'types': [u'route']}, {u'long_name': u'Reims', u'short_name': u'Reims', u'types': [u'locality', u'political']}, {u'long_name': u'Marne', u'short_name': u'Marne', u'types': [u'administrative_area_level_2', u'political']}, {u'long_name': u'Grand Est', u'short_name': u'Grand Est', u'types': [u'administrative_area_level_1', u'political']}, {u'long_name': u'France', u'short_name': u'FR', u'types': [u'country', u'political']}, {u'long_name': u'51687', u'short_name': u'51687', u'types': [u'postal_code']}], u'formatted_address': u'Rue des Cray\xe8res, 516
#
# {'../DHFR/groupes.renater.fr/sympa/arc/dh/2017-08/msg00007.html': {'Geo_Topic': {'content': "\nbonjour,\n\n \n\npeut-\xc3\xaatre cette information int\xc3\xa9ressera-t-elle des abonn\xc3\xa9s \xc3\xa0 cette liste : \nles archives nationales recrutent un ing\xc3\xa9nieur d'\xc3\xa9tudes, adjoint(e) au \nresponsable de la mission r\xc3\xa9f\xc3\xa9rentiels.\n\nla fiche de poste est publi\xc3\xa9e dans la bourse interminist\xc3\xa9rielle de l\xe2\x80\x99emploi \npublic (biep) sous le num\xc3\xa9ro 2017-70903.\n\nje la joins au pr\xc3\xa9sent message. elle est par ailleurs consultable ici : \nhttps://biep-recrute.talent-soft.com/offre-de-emploi/emploi--inge-adjoint-du-responsable-de-la-mission-referentiels-chef-de-projets-numeriques-h-f_70903.aspx\n\nle poste est ouvert aux contractuels ; la personne sera  recrut\xc3\xa9e sous \ncontrat pour une p\xc3\xa9riode de 3 ans renouvelable une fois.\n\nles candidatures sont \xc3\xa0 faire avant le 11 septembre en suivant les consignes \ndonn\xc3\x
#
# {'corinne de munain': [['corinne.de_munain@paris-sorbonne.fr', datetime.datetime(2015, 10, 26, 16, 5, 15, tzinfo=tzoffset(None, 3600)), datetime.datetime(2015, 10, 26, 16, 5, 15, tzinfo=tzoffset(None, 3600))]], 'jean-christophe carius': [['jccarius@gmail.com', datetime.datetime(2017, 1, 24, 13, 58, 13, tzinfo=tzoffset(None, 3600)), datetime.datetime(2017, 1, 24, 13, 58, 13, tzinfo=tzoffset(None, 3600))]], 'chlo\xc3\xa9 galibert-la\xc3\xaen\xc3\xa9': [['galibert@clipper.ens.fr', datetime.datetime(2015, 9, 28, 7, 3, 59, tzinfo=tzoffset(None, 7200)), datetime.datetime(2016, 1, 11, 14, 7, 12, tzinfo=tzoffset(None, 3600))]], 'st\xc3\xa9phane loret': [['stephane.loret@univ-nantes.fr', datetime.datetime(2015, 2, 24, 11, 38, 39, tzinfo=tzoffset(None, 3600)), datetime.datetime(2017, 8, 22, 10, 23, 11, tzinfo=tzoffset(None, 7200))]], 'alain marois': [['alain.marois@univ-lyon2.fr', datetime.datetime(2015, 6, 11, 15, 43, 25, tzinfo=tzlocal()), datetime.datetime(2018, 1, 29, 9, 35, 21, tzinfo=tzloc
#
# ['singrid.chene@enc.sorbonne.fr', 'dh@groupes.renater.fr', 'header.from=singrid.chene@enc.sorbonne.fr', 'sandrine.breuil@univ-tours.fr', 'slh@ens-lyon.fr', 'ln@cines.fr', 'corpus-ecrits@cru.fr', 'cahier@cru.fr', 'frederic@clavert.net', 'claire.clivaz@unil.ch', 'enrico.natale@infoclio.ch', 'dh@cru.fr', 'christine.kosmopoulos@parisgeo.cnrs.fr', 'marion.gentilhomme@gis-cist.fr', 'laurent.romary@inria.fr', 'risuciu@gmail.com', 'jerome.valluy@univ-paris1.fr', 'lou.burnard@retired.ox.ac.uk', 'tei-fr@groupes.renater.fr', 'tei-fr@cru.fr', 'frederic.clavert@uni.lu', 'kontorovichsofia@gmail.com', 'clarisse_bardiot@mac.com', 'nicolasthelyrennes2@gmail.com', 'martaseve@gmail.com', 'florian.harmand@gmail.com', 'formation.continue@enc-sorbonne.fr', 'michael.goudoux@sciencespo.fr', 'graham.ranger@univ-avignon.fr', 'saes@univ-pau.fr', 'alaes_liste@yahoogroupes.fr', 'delphine.cavallo@univ-amu.fr', 'bernard.jacquemin@univ-lille.fr', 'florence.clavaud@free.fr', 'ledamansour@hotmail.com', 'sylvia.girel@un

# %%
from datetime import timedelta
import datetime
# credentials
TOPOGRAM_URL = "http://localhost:3000"
USER = "gregory.bahde@laposte.net"
PASSWORD = "matrix"

# data
title = "DH_studies_map"
my_nodesdict = {}
my_nodes= []
my_edges = []


# date parsing
DATETIME_FORMAT = '%Y-%m-%dT%H:%M:%S'
DATETIME_FORMAT_FOR_MSBNZ ='%Y-%m-%d'



###FOR NODES
print len(dict_noms_mails_debut_fin)
print dict_noms_mails_debut_fin['claire clivaz']
#claire.clivaz@unil.ch
# Out:
# 772
# [['claire.clivaz@sib.swiss', datetime.datetime(2016, 3, 21, 17, 45, 25, tzinfo=tzoffset(None, 3600)), datetime.datetime(2018, 1, 31, 20, 52, 47, tzinfo=tzoffset(None, 3600))], ['claire.clivaz@unil.ch', datetime.datetime(2012, 10, 4, 0, 13, 29, tzinfo=tzoffset(None, 7200)), datetime.datetime(2016, 5, 19, 8, 52, 7, tzinfo=tzutc())], [['claire.clivaz@isb-sib.ch', datetime.datetime(2015, 8, 26, 4, 10, 39, tzinfo=tzoffset(None, 7200)), datetime.datetime(2016, 3, 28, 16, 0, 59, tzinfo=tzoffset(None, 7200))], ['claire.clivaz@unil.ch', datetime.datetime(2012, 10, 4, 0, 13, 29, tzinfo=tzoffset(None, 7200)), datetime.datetime(2016, 5, 19, 8, 52, 7, tzinfo=tzutc())]], [['claire.clivaz@isb-sib.ch', datetime.datetime(2015, 8, 26, 4, 10, 39, tzinfo=tzoffset(None, 7200)), datetime.datetime(2016, 3, 28, 16, 0, 59, tzinfo=tzoffset(None, 7200))], ['claire.clivaz@sib.swiss', datetime.datetime(2016, 3, 21, 17, 45, 25, tzinfo=tzoffset(None, 3600)), datetime.datetime(2018, 1, 31, 20, 52, 47, tzinfo=tzoffset(None, 3600))]]]

# %%
cnt=0
cnt_not_in_dict=0
liste_suffixes_absents=[]
for maill in liste_de_tous_les_mails:
    trouve=0
    #print maill
    for y in dict_noms_mails_debut_fin :
        for i,arr in enumerate(dict_noms_mails_debut_fin[y][0]):
            #rint "y", dict_noms_mails_debut_fin[y][0][i]
            
            if isinstance(dict_noms_mails_debut_fin[y][0][i], list) == True:
                print "!!!!!!list_in_arra",dict_noms_mails_debut_fin[y][0][i]
            else:
                if dict_noms_mails_debut_fin[y][0][i] == maill :
                        cnt+=1
                        trouve +=1
                        lat=None
                        lng=None


                        print "mail",maill.lower()
                        print "start",dict_noms_mails_debut_fin[y][0][i+1].strftime(DATETIME_FORMAT)
                        print "end",dict_noms_mails_debut_fin[y][0][i+2].strftime(DATETIME_FORMAT)
                        print "name",y.lower()



                        mail_address_suffix=dict_noms_mails_debut_fin[y][0][i].lower().split("@",1)[1]
                        print mail_address_suffix
                        try:
                            lat=dict_corrected_DH[mail_address_suffix.lower()]["geometry"]["location"]["lat"]
                            lng=dict_corrected_DH[mail_address_suffix.lower()]["geometry"]["location"]["lng"]
                            print "lat/lng ",lat," ",lng
                            print "________________"
                        except KeyError:
                            if mail_address_suffix.lower() not in liste_suffixes_absents:
                                liste_suffixes_absents.append(mail_address_suffix.lower())

                        try: 
                #print start
                #print end
                            node = {
                            "id" : maill.lower(),
                            "name" : y.lower(),
                           "lat" : float(lat),
                           "lng" : float(lng),
                           "weight" : float(4),
                            "start" : dict_noms_mails_debut_fin[y][0][i+1].strftime(DATETIME_FORMAT),

                           "end" : (dict_noms_mails_debut_fin[y][0][i+2]+timedelta(days=1)).strftime(DATETIME_FORMAT)
                            }
                        except AttributeError as e:
                            print "STARTSTART"
                            #print datetime.datetime(start[:-5])
                            print e

                            node = {
                                        "id" : maill.lower(),
                                        "name" : y.lower(),
                                       "lat" : float(lat),
                                       "lng" : float(lng),
                                       "weight" : float(4),
                                        "start" : datetime.datetime(2012, 3, 2, 15, 19, 10).strftime(DATETIME_FORMAT),

                                       "end" : datetime.datetime(2018, 3, 2, 15, 19, 10).strftime(DATETIME_FORMAT)
                                        }
                            print node
                        my_nodes.append({ "data" : node })   
                        my_nodesdict[node["id"]]= { "data" : node }
                    
    #SI LE MAIL N EST PAS DANS LE DICT DE NOMS(DONC QUE CE N EST PAS UN EXPEDITEUR)
    if trouve == 0:
        lat=None
        lng=None
        print "MAIL NOT IN NAME DICT: ", maill,"\n_________________"
        cnt_not_in_dict+=1
        mail_address_suffix=maill.lower().split("@",1)[1]
        print mail_address_suffix
        try:
            lat=dict_corrected_DH[mail_address_suffix.lower()]["geometry"]["location"]["lat"]
            lng=dict_corrected_DH[mail_address_suffix.lower()]["geometry"]["location"]["lng"]
            print "lat/lng ",lat," ",lng
            print "________________"
            try: 
            #print start
            #print end
                        node = {
                        "id" : dict_noms_mails_debut_fin[y][0][i].lower(),
                        "name" : y.lower(),
                       "lat" : float(lat),
                       "lng" : float(lng),
                       "weight" : float(4),
                        "start" : datetime.datetime(2012, 3, 2, 15, 19, 10).strftime(DATETIME_FORMAT),

                       "end" : datetime.datetime(2018, 3, 2, 15, 19, 10).strftime(DATETIME_FORMAT)
                        }
            except AttributeError as e:
                        print "STARTSTART2"
                        print e

                        node = {
                                    "id" : maill.lower(),
                                    "name" : maill.lower(),
                                   "lat" : float(lat),
                                   "lng" : float(lng),
                                   "weight" : float(4),
                                    "start" : datetime.datetime(2012, 3, 2, 15, 19, 10).strftime(DATETIME_FORMAT),

                                   "end" : datetime.datetime(2018, 3, 2, 15, 19, 10).strftime(DATETIME_FORMAT)
                                    }
        except KeyError:
                            if mail_address_suffix.lower() not in liste_suffixes_absents:
                                liste_suffixes_absents.append(mail_address_suffix.lower())

        

        my_nodes.append({ "data" : node })   
        my_nodesdict[node["id"]]= { "data" : node }
        print node,"\n----------------\n"

        
        
        
        
        
        
        
        
        
        
        
        
    
    
print len(my_nodesdict)
    
                    
                    
                    
                
print "<<<<<<<<<<<COUNT NODES>>>>>>>>>>>>>",cnt
print "<<<<<<COUNT NODES NOT IN DICT>>>>>>",cnt_not_in_dict
print "<<<<<<<<<TOTAL>>>>>>>",cnt_not_in_dict+cnt


    
print len(my_nodesdict)
print liste_suffixes_absents
# Out:
# mail singrid.chene@enc.sorbonne.fr
# start 2014-04-10T10:10:37
# end 2016-05-03T09:16:39
# name chene singrid
# enc.sorbonne.fr
# lat/lng  48.8673191   2.3374701
# ________________
# mail singrid.chene@enc.sorbonne.fr
# start 2014-04-10T10:10:37
# end 2016-05-03T09:16:39
# name singrid chëne
# enc.sorbonne.fr
# lat/lng  48.8673191   2.3374701
# ________________
# MAIL NOT IN NAME DICT:  dh@groupes.renater.fr
# _________________
# groupes.renater.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'dh@groupes.renater.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'dh@groupes.renater.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  header.from=singrid.chene@enc.sorbonne.fr
# _________________
# enc.sorbonne.fr
# lat/lng  48.8673191   2.3374701
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'header.from=singrid.chene@enc.sorbonne.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8673191, 'lng': 2.3374701, 'id': 'header.from=singrid.chene@enc.sorbonne.fr'}
# ----------------
#
# mail sandrine.breuil@univ-tours.fr
# start 2010-11-22T11:33:29
# end 2017-12-18T17:12:12
# name sandrine breuil
# univ-tours.fr
# lat/lng  47.3838055   0.6738728
# ________________
# mail slh@ens-lyon.fr
# start 2011-04-01T11:06:12
# end 2018-03-15T11:33:42
# name heiden serge
# ens-lyon.fr
# lat/lng  45.7298448   4.8285332
# ________________
# mail slh@ens-lyon.fr
# start 2011-04-01T11:06:12
# end 2018-03-15T11:33:42
# name serge heiden
# ens-lyon.fr
# lat/lng  45.7298448   4.8285332
# ________________
# MAIL NOT IN NAME DICT:  ln@cines.fr
# _________________
# cines.fr
# lat/lng  43.6362031   3.8418738
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'ln@cines.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 43.6362031, 'lng': 3.8418738, 'id': 'ln@cines.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  corpus-ecrits@cru.fr
# _________________
# cru.fr
# lat/lng  48.8594257   2.3465053
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'corpus-ecrits@cru.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8594257, 'lng': 2.3465053, 'id': 'corpus-ecrits@cru.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  cahier@cru.fr
# _________________
# cru.fr
# lat/lng  48.8594257   2.3465053
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'cahier@cru.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8594257, 'lng': 2.3465053, 'id': 'cahier@cru.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  frederic@clavert.net
# _________________
# clavert.net
# lat/lng  48.8218676   2.3708981
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'frederic@clavert.net', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8218676, 'lng': 2.3708981, 'id': 'frederic@clavert.net'}
# ----------------
#
# mail claire.clivaz@unil.ch
# start 2012-10-04T00:13:29
# end 2016-05-19T08:52:07
# name clivaz claire
# unil.ch
# lat/lng  46.5210895   6.5801606
# ________________
# mail enrico.natale@infoclio.ch
# start 2011-09-21T16:37:48
# end 2017-12-20T14:44:45
# name enrico natale
# infoclio.ch
# lat/lng  48.5139138897   -27.0818994565
# ________________
# MAIL NOT IN NAME DICT:  dh@cru.fr
# _________________
# cru.fr
# lat/lng  48.8594257   2.3465053
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'dh@cru.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8594257, 'lng': 2.3465053, 'id': 'dh@cru.fr'}
# ----------------
#
# mail christine.kosmopoulos@parisgeo.cnrs.fr
# start 2013-10-14T13:09:57
# end 2016-01-27T14:35:39
# name christine kosmopoulos
# parisgeo.cnrs.fr
# lat/lng  48.8476037   2.2639934
# ________________
# mail marion.gentilhomme@gis-cist.fr
# start 2014-08-05T14:43:03
# end 2017-09-08T12:00:28
# name marion gentilhomme
# gis-cist.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# mail laurent.romary@inria.fr
# start 2013-03-15T14:49:25
# end 2016-10-14T14:14:17
# name laurent romary
# inria.fr
# lat/lng  45.7862471   4.8797456
# ________________
# mail risuciu@gmail.com
# start 2011-04-14T15:51:28
# end 2015-11-24T18:45:24
# name radu suciu
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# MAIL NOT IN NAME DICT:  jerome.valluy@univ-paris1.fr
# _________________
# univ-paris1.fr
# lat/lng  48.8469373   2.344468
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'jerome.valluy@univ-paris1.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8469373, 'lng': 2.344468, 'id': 'jerome.valluy@univ-paris1.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  lou.burnard@retired.ox.ac.uk
# _________________
# retired.ox.ac.uk
# lat/lng  51.7548164   -1.2543668
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'lou.burnard@retired.ox.ac.uk', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 51.7548164, 'lng': -1.2543668, 'id': 'lou.burnard@retired.ox.ac.uk'}
# ----------------
#
# MAIL NOT IN NAME DICT:  tei-fr@groupes.renater.fr
# _________________
# groupes.renater.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'tei-fr@groupes.renater.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'tei-fr@groupes.renater.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  tei-fr@cru.fr
# _________________
# cru.fr
# lat/lng  48.8594257   2.3465053
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'tei-fr@cru.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8594257, 'lng': 2.3465053, 'id': 'tei-fr@cru.fr'}
# ----------------
#
# mail frederic.clavert@uni.lu
# start 2017-09-29T09:24:17
# end 2018-05-01T00:00:00
# name frédéric clavert
# uni.lu
# lat/lng  49.504254   5.948386
# ________________
# mail kontorovichsofia@gmail.com
# start 2018-02-20T13:23:13
# end 2018-02-20T13:23:13
# name Софья Конторович
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# MAIL NOT IN NAME DICT:  clarisse_bardiot@mac.com
# _________________
# mac.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'clarisse_bardiot@mac.com', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'clarisse_bardiot@mac.com'}
# ----------------
#
# mail nicolasthelyrennes2@gmail.com
# start 2014-11-12T08:28:50
# end 2017-06-12T14:18:46
# name nicolas thély
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# mail martaseve@gmail.com
# start 2014-09-19T11:04:40
# end 2018-02-28T14:21:45
# name marta severo
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# mail florian.harmand@gmail.com
# start 2018-02-13T15:38:53
# end 2018-02-13T15:38:53
# name florian harmand
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# mail formation.continue@enc-sorbonne.fr
# start 2016-07-05T15:46:59
# end 2018-02-02T14:26:36
# name formation continue enc
# enc-sorbonne.fr
# lat/lng  48.8673191   2.3374701
# ________________
# mail formation.continue@enc-sorbonne.fr
# start 2016-07-05T15:46:59
# end 2018-02-02T14:26:36
# name formation continue
# enc-sorbonne.fr
# lat/lng  48.8673191   2.3374701
# ________________
# mail michael.goudoux@sciencespo.fr
# start 2018-02-05T15:49:04
# end 2018-02-05T15:49:04
# name michaël goudoux
# sciencespo.fr
# lat/lng  48.8540917   2.3283745
# ________________
# mail graham.ranger@univ-avignon.fr
# start 2018-02-01T09:48:02
# end 2018-03-15T20:45:58
# name graham ranger -- uapv
# univ-avignon.fr
# lat/lng  43.9492289   4.8181272
# ________________
# mail graham.ranger@univ-avignon.fr
# start 2018-02-01T09:48:02
# end 2018-03-15T20:45:58
# name graham ranger
# univ-avignon.fr
# lat/lng  43.9492289   4.8181272
# ________________
# MAIL NOT IN NAME DICT:  saes@univ-pau.fr
# _________________
# univ-pau.fr
# lat/lng  43.3150753   -0.365641
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'saes@univ-pau.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 43.3150753, 'lng': -0.365641, 'id': 'saes@univ-pau.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  alaes_liste@yahoogroupes.fr
# _________________
# yahoogroupes.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'alaes_liste@yahoogroupes.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'alaes_liste@yahoogroupes.fr'}
# ----------------
#
# mail delphine.cavallo@univ-amu.fr
# start 2012-10-26T11:55:28
# end 2018-03-29T10:23:54
# name cavallo delphine
# univ-amu.fr
# lat/lng  43.293621   5.358066
# ________________
# mail delphine.cavallo@univ-amu.fr
# start 2012-10-26T11:55:28
# end 2018-03-29T10:23:54
# name delphine cavallo
# univ-amu.fr
# lat/lng  43.293621   5.358066
# ________________
# mail bernard.jacquemin@univ-lille.fr
# start 2018-02-20T11:28:46
# end 2018-02-26T16:08:26
# name bernard jacquemin
# univ-lille.fr
# lat/lng  50.609049   3.138063
# ________________
# mail florence.clavaud@free.fr
# start 2012-09-20T13:10:21
# end 2018-03-02T15:36:05
# name florence.clavaud@free.fr
# free.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# mail ledamansour@hotmail.com
# start 2013-05-27T13:17:12
# end 2018-02-27T17:03:56
# name léda mansour
# hotmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# mail ledamansour@hotmail.com
# start 2013-05-27T13:17:12
# end 2018-02-27T17:03:56
# name mansour léda
# hotmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# mail sylvia.girel@univ-amu.fr
# start 2018-02-12T10:24:29
# end 2018-02-12T10:24:29
# name sylvia girel
# univ-amu.fr
# lat/lng  43.293621   5.358066
# ________________
# MAIL NOT IN NAME DICT:  corpora@uib.no
# _________________
# uib.no
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'corpora@uib.no', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'corpora@uib.no'}
# ----------------
#
# MAIL NOT IN NAME DICT:  parislinguists@yahoogroupes.fr
# _________________
# yahoogroupes.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'parislinguists@yahoogroupes.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'parislinguists@yahoogroupes.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  studiidelingvistica@uoradea.ro
# _________________
# uoradea.ro
# lat/lng  47.0447631   21.9181616
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'studiidelingvistica@uoradea.ro', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 47.0447631, 'lng': 21.9181616, 'id': 'studiidelingvistica@uoradea.ro'}
# ----------------
#
# MAIL NOT IN NAME DICT:  agorantic@listes.univ-avignon.fr
# _________________
# listes.univ-avignon.fr
# lat/lng  43.9492289   4.8181272
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'agorantic@listes.univ-avignon.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 43.9492289, 'lng': 4.8181272, 'id': 'agorantic@listes.univ-avignon.fr'}
# ----------------
#
# mail carmen.brando@ehess.fr
# start 2017-05-15T10:50:36
# end 2018-02-20T08:19:57
# name brando carmen
# ehess.fr
# lat/lng  48.850174   2.3268487
# ________________
# MAIL NOT IN NAME DICT:  jouni.tuominen@helsinki.fi
# _________________
# helsinki.fi
# lat/lng  60.2237993   25.0174366
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'jouni.tuominen@helsinki.fi', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 60.2237993, 'lng': 25.0174366, 'id': 'jouni.tuominen@helsinki.fi'}
# ----------------
#
# mail annael.le-poullennec@psl.eu
# start 2018-02-27T16:50:22
# end 2018-03-01T14:03:55
# name annael le poullennec
# psl.eu
# lat/lng  48.8864969   2.3130983
# ________________
# mail geraldine.castel@univ-grenoble-alpes.fr
# start 2016-03-31T14:36:49
# end 2018-02-14T17:25:22
# name geraldine castel
# univ-grenoble-alpes.fr
# lat/lng  45.1914198   5.7672724
# ________________
# mail dina.bacalexi@cnrs.fr
# start 2018-02-19T20:03:18
# end 2018-02-19T20:06:50
# name dina bacalexi
# cnrs.fr
# lat/lng  45.203453   5.700236
# ________________
# MAIL NOT IN NAME DICT:  tlm@ehess.fr
# _________________
# ehess.fr
# lat/lng  48.850174   2.3268487
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'tlm@ehess.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.850174, 'lng': 2.3268487, 'id': 'tlm@ehess.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  florence.neveux@ehess.fr
# _________________
# ehess.fr
# lat/lng  48.850174   2.3268487
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'florence.neveux@ehess.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.850174, 'lng': 2.3268487, 'id': 'florence.neveux@ehess.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:
fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# mail listes@ahicf.com
# start 2013-07-18T10:20:44
# end 2018-03-28T16:43:54
# name listes@ahicf.com
# ahicf.com
# lat/lng  48.8801078   2.3621086
# ________________
# mail listes@ahicf.com
# start 2013-07-18T10:20:44
# end 2018-03-28T16:43:54
# name rails &amp; histoire
# ahicf.com
# lat/lng  48.8801078   2.3621086
# ________________
# mail laurence.mellerin@gmail.com
# start 2018-02-24T18:02:20
# end 2018-02-24T18:02:20
# name laurence mellerin
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# mail aurele.crasson@ens.fr
# start 2018-02-19T16:55:13
# end 2018-02-19T16:55:13
# name aurèle crasson
# ens.fr
# lat/lng  48.8422058   2.3451689
# ________________
# mail mehdi.khamassi@upmc.fr
# start 2015-12-29T10:45:32
# end 2018-02-15T12:10:26
# name mehdi khamassi
# upmc.fr
# lat/lng  48.8471036   2.357499
# ________________
# MAIL NOT IN NAME DICT:  michel.bernard@univ-paris3.fr
# _________________
# univ-paris3.fr
# lat/lng  48.8397962   2.3538807
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'michel.bernard@univ-paris3.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.83979619999999, 'lng': 2.3538807, 'id': 'michel.bernard@univ-paris3.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  litor@listes.univ-paris3.fr
# _________________
# listes.univ-paris3.fr
# lat/lng  48.8469373   2.344468
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'litor@listes.univ-paris3.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8469373, 'lng': 2.344468, 'id': 'litor@listes.univ-paris3.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  numeruniv-quotidien@cines.fr
# _________________
# cines.fr
# lat/lng  43.6362031   3.8418738
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'numeruniv-quotidien@cines.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 43.6362031, 'lng': 3.8418738, 'id': 'numeruniv-quotidien@cines.fr'}
# ----------------
#
# mail claire.lemercier@sciencespo.fr
# start 2014-03-20T15:15:45
# end 2018-03-14T10:03:02
# name claire lemercier
# sciencespo.fr
# lat/lng  48.8540917   2.3283745
# ________________
# mail laurence.mace-delvento@univ-rouen.fr
# start 2018-02-19T21:49:57
# end 2018-02-19T21:49:57
# name laurence macé
# univ-rouen.fr
# lat/lng  49.4583047   1.0688892
# ________________
# mail matteo.treleani@univ-lille3.fr
# start 2017-10-24T12:28:48
# end 2018-02-27T11:47:23
# name matteo treleani
# univ-lille3.fr
# lat/lng  50.627577   3.126726
# ________________
# MAIL NOT IN NAME DICT:  txm-users@cru.fr
# _________________
# cru.fr
# lat/lng  48.8594257   2.3465053
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'txm-users@cru.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8594257, 'lng': 2.3465053, 'id': 'txm-users@cru.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  vial.stephane@gmail.com
# _________________
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'vial.stephane@gmail.com', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'vial.stephane@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  recherche-design@listes.univ-paris1.fr
# _________________
# listes.univ-paris1.fr
# lat/lng  48.8469373   2.344468
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'recherche-design@listes.univ-paris1.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8469373, 'lng': 2.344468, 'id': 'recherche-design@listes.univ-paris1.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  communication@unimes.fr
# _________________
# unimes.fr
# lat/lng  43.8424986   4.3569947
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'communication@unimes.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 43.8424986, 'lng': 4.3569947, 'id': 'communication@unimes.fr'}
# ----------------
#
# mail dbernhard@unistra.fr
# start 2018-02-12T10:10:42
# end 2018-03-26T12:32:35
# name dbernhard@unistra.fr
# unistra.fr
# lat/lng  48.5790692   7.7664545
# ________________
# MAIL NOT IN NAME DICT:  legram@yahoogroupes.fr
# _________________
# yahoogroupes.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'legram@yahoogroupes.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'legram@yahoogroupes.fr'}
# ----------------
#
# mail nora.gueliane@ehess.fr
# start 2018-02-19T16:13:35
# end 2018-02-19T16:13:35
# name gueliane nora
# ehess.fr
# lat/lng  48.850174   2.3268487
# ________________
# m
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# mail annelyse.renon@gmail.com
# start 2011-04-14T15:35:00
# end 2017-11-07T08:18:40
# name renon anne-lyse
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# mail pierre.mounier@openedition.org
# start 2012-10-03T08:22:28
# end 2018-03-05T11:11:00
# name pierre mounier
# openedition.org
# lat/lng  48.5139138897   -27.0818994565
# ________________
# MAIL NOT IN NAME DICT:  claire.lemercier@sciences-po.org
# _________________
# sciences-po.org
# lat/lng  48.8540917   2.3283745
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'claire.lemercier@sciences-po.org', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8540917, 'lng': 2.3283745, 'id': 'claire.lemercier@sciences-po.org'}
# ----------------
#
# MAIL NOT IN NAME DICT:  marin.dacos@openedition.org
# _________________
# openedition.org
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'marin.dacos@openedition.org', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'marin.dacos@openedition.org'}
# ----------------
#
# mail proulx.serge@uqam.ca
# start 2013-05-13T15:16:03
# end 2017-07-17T13:17:30
# name serge proulx
# uqam.ca
# lat/lng  45.5125995   -73.5605955
# ________________
# mail proulx.serge@uqam.ca
# start 2013-05-13T15:16:03
# end 2017-07-17T13:17:30
# name proulx, serge
# uqam.ca
# lat/lng  45.5125995   -73.5605955
# ________________
# mail ph.godard@free.fr
# start 2013-05-13T14:49:55
# end 2014-04-02T17:59:27
# name ph.godard@free.fr
# free.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# mail annaig.mahe@enc.sorbonne.fr
# start 2013-05-02T09:28:04
# end 2013-05-02T09:28:04
# name annaig mahe
# enc.sorbonne.fr
# lat/lng  48.8673191   2.3374701
# ________________
# mail ines.demontesquieu@openedition.org
# start 2013-05-13T11:38:58
# end 2013-05-13T11:38:58
# name inès secondat de montesquieu
# openedition.org
# lat/lng  48.5139138897   -27.0818994565
# ________________
# mail gabriel.garrote@universite-lyon.fr
# start 2013-05-27T17:00:45
# end 2013-05-27T17:00:45
# name gabriel garrote
# universite-lyon.fr
# lat/lng  45.7494529   4.8371497
# ________________
# mail marcello.vitali-rosati@sens-public.org
# start 2011-11-03T10:01:59
# end 2016-01-04T09:36:08
# name marcello vitali rosati
# sens-public.org
# lat/lng  45.7552626   4.8421419
# ________________
# mail dominique.stutzmann@irht.cnrs.fr
# start 2012-01-06T14:45:06
# end 2017-10-13T09:05:17
# name dominique stutzmann
# irht.cnrs.fr
# lat/lng  48.8664818   2.2954043
# ________________
# mail jean.philippe.mague@gmail.com
# start 2013-05-21T13:59:57
# end 2013-05-21T13:59:57
# name jean-philippe magué
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# MAIL NOT IN NAME DICT:  constance@giantchair.com
# _________________
# giantchair.com
# lat/lng  40.7459285   -73.9888338
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'constance@giantchair.com', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 40.7459285, 'lng': -73.9888338, 'id': 'constance@giantchair.com'}
# ----------------
#
# mail remi.jimenes@gmail.com
# start 2012-11-21T10:09:16
# end 2017-11-28T10:36:39
# name rémi jimenes
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# mail antoine.blanchard@gmail.com
# start 2011-03-04T23:15:10
# end 2014-04-15T16:00:16
# name antoine blanchard
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# mail serge.noiret@eui.eu
# start 2010-05-20T12:58:45
# end 2016-01-25T09:20:41
# name noiret, serge
# eui.eu
# lat/lng  43.803079   11.282959
# ________________
# mail serge.noiret@eui.eu
# start 2010-05-20T12:58:45
# end 2016-01-25T09:20:41
# name serge.noiret@eui.eu
# eui.eu
# lat/lng  43.803079   11.282959
# ________________
# mail francoise.paquienseguy@sciencespo-lyon.fr
# start 2012-10-01T06:54:11
# end 2017-06-16T18:12:58
# name paquien-séguy françoise
# sciencespo-lyon.fr
fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  eric@eric.univ-lyon2.fr
# _________________
# eric.univ-lyon2.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'eric@eric.univ-lyon2.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'eric@eric.univ-lyon2.fr'}
# ----------------
#
# mail claire.clivaz@sib.swiss
# start 2016-03-21T17:45:25
# end 2018-01-31T20:52:47
# name claire clivaz
# sib.swiss
# lat/lng  46.1935442   6.1489695
# ________________
# mail dumouchelsuzanne@yahoo.fr
# start 2016-09-30T07:20:28
# end 2018-03-29T06:51:33
# name dumouchel suzanne
# yahoo.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# mail marie-astrid.hugel@wanadoo.fr
# start 2016-12-21T11:46:40
# end 2016-12-21T11:46:40
# name marie hugel
# wanadoo.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# mail singrid.chene@enc-sorbonne.fr
# start 2016-09-15T11:04:30
# end 2017-01-31T09:53:51
# name singrid chêne
# enc-sorbonne.fr
# lat/lng  48.8673191   2.3374701
# ________________
# mail anne.geslin87@orange.fr
# start 2016-12-01T18:33:42
# end 2016-12-01T18:33:42
# name anne geslin
# orange.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# MAIL NOT IN NAME DICT:  aamonnz@gmail.com
# _________________
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'aamonnz@gmail.com', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'aamonnz@gmail.com'}
# ----------------
#
# mail rojas.castro.antonio@gmail.com
# start 2016-01-28T20:19:52
# end 2017-02-19T09:18:02
# name antonio rojas castro
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# MAIL NOT IN NAME DICT:  culture.numerique@ml.free.fr
# _________________
# ml.free.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'culture.numerique@ml.free.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'culture.numerique@ml.free.fr'}
# ----------------
#
# mail zghal.sami@gmail.com
# start 2016-12-20T16:32:38
# end 2016-12-20T16:32:38
# name sami zghal
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# MAIL NOT IN NAME DICT:  list-egc@polytech.univ-nantes.fr
# _________________
# polytech.univ-nantes.fr
# lat/lng  47.2820804   -1.5160328
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'list-egc@polytech.univ-nantes.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 47.2820804, 'lng': -1.5160328, 'id': 'list-egc@polytech.univ-nantes.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  info-ic@listes.irisa.fr
# _________________
# listes.irisa.fr
# lat/lng  48.1163181   -1.6397024
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'info-ic@listes.irisa.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.1163181, 'lng': -1.6397024, 'id': 'info-ic@listes.irisa.fr'}
# ----------------
#
# mail guillaume.cabanac@univ-tlse3.fr
# start 2016-12-24T09:14:07
# end 2017-02-27T14:41:27
# name guillaume cabanac
# univ-tlse3.fr
# lat/lng  43.5619687   1.4700537
# ________________
# MAIL NOT IN NAME DICT:  info-aria@lsis.org
# _________________
# lsis.org
# lat/lng  48.8217849   2.3709825
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'info-aria@lsis.org', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8217849, 'lng': 2.3709825, 'id': 'info-aria@lsis.org'}
# ----------------
#
# MAIL NOT IN NAME DICT:  doccitanist@services.cnrs.fr
# _________________
# services.cnrs.fr
# lat/lng  45.203453   5.700236
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'doccitanist@services.cnrs.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 45.203453, 'lng': 5.700235999999999, 'id': 'doccitanist@services.cnrs.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  accesouvert@groupes.renater.fr
# _________________
# groupes.renater.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'accesouvert@groupes.renater.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'accesouvert@groupes.renater.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  aotoulouse@univ-tlse2.fr
# _________________
# univ-tlse2.fr
# lat/lng  43.5795225   1.4032247
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'aotoulouse@univ-tlse2.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 43.5795225, 'lng': 1.4032247, 'id': 'aotoulouse@univ-tlse2.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  lyne.da.sylva@umontreal.ca
# _________________
# umontreal.ca
# lat/lng  45.5056156   -73.6137592
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'lyne.da.sylva@umontreal.ca', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 45
fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8335842, 'lng': 2.3757659, 'id': 'fabienne.le-bars@bnf.fr'}
# ----------------
#
# mail vpringuet@gmail.com
# start 2016-12-28T10:20:05
# end 2017-01-26T19:01:58
# name virginie pringuet
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# mail emilie.groshens@sciencespo.fr
# start 2015-10-16T15:24:40
# end 2017-10-18T12:02:09
# name bequali cdsp
# sciencespo.fr
# lat/lng  48.8540917   2.3283745
# ________________
# mail emilie.groshens@sciencespo.fr
# start 2015-10-16T15:24:40
# end 2017-10-18T12:02:09
# name emilie groshens
# sciencespo.fr
# lat/lng  48.8540917   2.3283745
# ________________
# mail sonia.litaiem@hesam.eu
# start 2016-12-01T12:15:06
# end 2016-12-01T12:15:06
# name sonia.litaiem@hesam.eu
# hesam.eu
# lat/lng  48.8469649   2.3420435
# ________________
# MAIL NOT IN NAME DICT:  thomaslebarbe@gmail.com
# _________________
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'thomaslebarbe@gmail.com', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'thomaslebarbe@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  pierre.mounier@revues.org
# _________________
# revues.org
# lat/lng  43.949162   4.8282792
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'pierre.mounier@revues.org', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 43.949162, 'lng': 4.8282792, 'id': 'pierre.mounier@revues.org'}
# ----------------
#
# mail mkoenig@dhi-paris.fr
# start 2011-02-04T09:28:54
# end 2017-06-14T14:57:17
# name mareike koenig
# dhi-paris.fr
# lat/lng  48.8586809   2.3635197
# ________________
# mail anne-laure.brisac@inha.fr
# start 2010-03-26T11:02:02
# end 2014-09-30T15:53:11
# name anne-laure brisac
# inha.fr
# lat/lng  48.8663364   2.3388561
# ________________
# mail anne-laure.brisac@inha.fr
# start 2010-03-26T11:02:02
# end 2014-09-30T15:53:11
# name anne-laure brisac-chraïbi
# inha.fr
# lat/lng  48.8663364   2.3388561
# ________________
# mail anne-laure.brisac@inha.fr
# start 2010-03-26T11:02:02
# end 2014-09-30T15:53:11
# name anne-laure.brisac@inha.fr
# inha.fr
# lat/lng  48.8663364   2.3388561
# ________________
# mail maud.ingarao@ens-lyon.fr
# start 2011-05-11T09:00:56
# end 2017-12-07T13:35:45
# name ingarao maud
# ens-lyon.fr
# lat/lng  45.7298448   4.8285332
# ________________
# mail maud.ingarao@ens-lyon.fr
# start 2011-05-11T09:00:56
# end 2017-12-07T13:35:45
# name maud ingarao
# ens-lyon.fr
# lat/lng  45.7298448   4.8285332
# ________________
# MAIL NOT IN NAME DICT:  ahn-diff@ens-lyon.fr
# _________________
# ens-lyon.fr
# lat/lng  45.7298448   4.8285332
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'ahn-diff@ens-lyon.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 45.7298448, 'lng': 4.8285332, 'id': 'ahn-diff@ens-lyon.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  mutec-info@cru.fr
# _________________
# cru.fr
# lat/lng  48.8594257   2.3465053
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'mutec-info@cru.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8594257, 'lng': 2.3465053, 'id': 'mutec-info@cru.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  corinne.welger@sfr.fr
# _________________
# sfr.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'corinne.welger@sfr.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'corinne.welger@sfr.fr'}
# ----------------
#
# mail svhoolan@ulb.ac.be
# start 2012-06-18T18:15:04
# end 2018-03-29T15:57:02
# name seth van hooland
# ulb.ac.be
# lat/lng  50.8132068   4.3822222
# ________________
# mail paul.girard@sciences-po.fr
# start 2011-04-14T14:47:14
# end 2012-06-05T19:42:18
# name paul girard
# sciences-po.fr
# lat/lng  48.8540917   2.3283745
# ________________
# MAIL NOT IN NAME DICT:  info@infoclio.ch
# _________________
# infoclio.ch
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# ...
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'julien.rabaud@college-de-france.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8488839, 'lng': 2.3454896, 'id': 'julien.rabaud@college-de-france.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  juliette.hueber@inha.fr
# _________________
# inha.fr
# lat/lng  48.8663364   2.3388561
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'juliette.hueber@inha.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.86633639999999, 'lng': 2.3388561, 'id': 'juliette.hueber@inha.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  karinelebrun@wanadoo.fr
# _________________
# wanadoo.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'karinelebrun@wanadoo.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'karinelebrun@wanadoo.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  labo@serandour.com
# _________________
# serandour.com
# lat/lng  7.198851   5.593239
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'labo@serandour.com', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 7.198850999999999, 'lng': 5.593239, 'id': 'labo@serandour.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  marie-claude.zikra@univ-paris1.fr
# _________________
# univ-paris1.fr
# lat/lng  48.8469373   2.344468
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'marie-claude.zikra@univ-paris1.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8469373, 'lng': 2.344468, 'id': 'marie-claude.zikra@univ-paris1.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  martine.cocaud@univ-rennes2.fr
# _________________
# univ-rennes2.fr
# lat/lng  48.1179154   -1.7028658
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'martine.cocaud@univ-rennes2.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.1179154, 'lng': -1.7028658, 'id': 'martine.cocaud@univ-rennes2.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  mayhoua@yahoo.fr
# _________________
# yahoo.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'mayhoua@yahoo.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'mayhoua@yahoo.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  ndobreva@msh-paris.fr
# _________________
# msh-paris.fr
# lat/lng  48.850142   2.3269827
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'ndobreva@msh-paris.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.850142, 'lng': 2.3269827, 'id': 'ndobreva@msh-paris.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  nicolas.richard@univ-rennes2.fr
# _________________
# univ-rennes2.fr
# lat/lng  48.1179154   -1.7028658
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'nicolas.richard@univ-rennes2.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.1179154, 'lng': -1.7028658, 'id': 'nicolas.richard@univ-rennes2.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  philippe.lagadec@univ-brest.fr
# _________________
# univ-brest.fr
# lat/lng  48.3980356   -4.5076415
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'philippe.lagadec@univ-brest.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.3980356, 'lng': -4.5076415, 'id': 'philippe.lagadec@univ-brest.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  regis.robineau@biblissima-condorcet.fr
# _________________
# biblissima-condorcet.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'regis.robineau@biblissima-condorcet.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'regis.robineau@biblissima-condorcet.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  wonga@laposte.net
# _________________
# laposte.net
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'wonga@laposte.net', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'wonga@laposte.net'}
# ----------------
#
# MAIL NOT IN NAME DICT:  yves.picard@uhb.fr
# _________________
# uhb.fr
# lat/lng  48.1179154   -1.7028658
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'yves.picard@uhb.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.1179154, 'lng': -1.7028658, 'id': 'yves.picard@uhb.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  alexandre.serres@uhb.fr
# _________________
# uhb.fr
# lat/lng  48.1179154   -1.7028658
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'alexandre.serres@uhb.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.1179154, 'lng': -1.7028658, 'id': 'alexandre.serres@uhb.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  alexis.chazard@esad-gv.fr
# _________________
# esad-gv.fr
# lat/lng  44.9300203   4.9263758
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'alexis.chazard@esad-gv.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 44.9300203, 'lng': 4.9263758, 'id': 'alexis.chazard@esad-gv.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  loupcellard@gmail.com
# _________________
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'loupcellard@gmail.com', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'loupcellard@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  christophe.leclercq@sciencespo.fr
# _________________
# sciencespo.fr
# lat/lng  48.8540917   2.3283745
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'christophe.leclercq@sciencespo.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8540917, 'lng': 2.3283745, 'id': 'christophe.leclercq@sciencespo.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  erwan.mahe.artefacto@gmail.com
# _________________
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'erwan.mahe.artefacto@gmail.com', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'erwan.mahe.artefacto@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  tonnellier.gaelle@gmail.com
# _________________
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'tonnellier.gaelle@gmail.com', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'tonnellier.gaelle@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  guillaume.queruel@unicaen.fr
# _________________
# unicaen.fr
# lat/lng  49.188971   -0.363888
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'guillaume.queruel@unicaen.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 49.188971, 'lng': -0.363888, 'id': 'guillaume.queruel@unicaen.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  laurent.flamand@region-bretagne.fr
# _________________
# region-bretagne.fr
# lat/lng  48.2020471   -2.9326435
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'laurent.flamand@region-bretagne.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.2020471, 'lng': -2.9326435, 'id': 'laurent.flamand@region-bretagne.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  laurent.sellin@gmail.com
# _________________
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'laurent.sellin@gmail.com', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'laurent.sellin@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  sev.giordan@gmail.com
# _________________
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'sev.giordan@gmail.com', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'sev.giordan@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  carmes.cnam@orange.fr
# _________________
# orange.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'carmes.cnam@orange.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'carmes.cnam@orange.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  pierre.braun@univ-rennes2.fr
# _________________
# univ-rennes2.fr
# lat/lng  48.1179154   -1.7028658
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'pierre.braun@univ-rennes2.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.1179154, 'lng': -1.7028658, 'id': 'pierre.braun@univ-rennes2.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  robin.demourat@gmail.com
# _________________
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'robin.demourat@gmail.com', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'robin.demourat@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  rtrillard@gmail.com
# _________________
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'rtrillard@gmail.com', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'rtrillard@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  auger.valere@gmail.com
# _________________
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'auger.valere@gmail.com', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'auger.valere@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  victor.petit@yahoo.fr
# _________________
# yahoo.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'victor.petit@yahoo.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'victor.petit@yahoo.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  yan.alary@gmail.com
# _________________
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'yan.alary@gmail.com', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'yan.alary@gmail.com'}
# ----------------
#
# mail anne-solweig.gremillet@ehess.fr
# start 2011-02-23T11:25:50
# end 2012-01-10T12:16:25
# name gremillet anne-solweig
# ehess.fr
# lat/lng  48.850174   2.3268487
# ________________
# MAIL NOT IN NAME DICT:  marieke.fornerod@gmail.com
# _________________
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'marieke.fornerod@gmail.com', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'marieke.fornerod@gmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  debora.bertol@inha.fr
# _________________
# inha.fr
# lat/lng  48.8663364   2.3388561
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'debora.bertol@inha.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.86633639999999, 'lng': 2.3388561, 'id': 'debora.bertol@inha.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  katia.bienvenu@hotmail.com
# _________________
# hotmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'katia.bienvenu@hotmail.com', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'katia.bienvenu@hotmail.com'}
# ----------------
#
# MAIL NOT IN NAME DICT:  yves.jeanneret@paris-sorbonne.fr-yves.jeanneret
# _________________
# paris-sorbonne.fr-yves.jeanneret
# lat/lng  48.8483803   2.3434592
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'yves.jeanneret@paris-sorbonne.fr-yves.jeanneret', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8483803, 'lng': 2.3434592, 'id': 'yves.jeanneret@paris-sorbonne.fr-yves.jeanneret'}
# ----------------
#
# MAIL NOT IN NAME DICT:  stavrou@orange.fr
# _________________
# orange.fr
# lat/lng  48.5139138897   -27.0818994565
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'stavrou@orange.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'stavrou@orange.fr'}
# ----------------
#
# mail magravoux@hotmail.com
# start 2011-02-11T22:11:53
# end 2011-02-11T22:11:53
# name magali ravoux
# hotmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# MAIL NOT IN NAME DICT:  melanie.dulong-de-rosnay@iscc.cnrs.fr
# _________________
# iscc.cnrs.fr
# lat/lng  48.8354443   2.350382
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'melanie.dulong-de-rosnay@iscc.cnrs.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.83544430000001, 'lng': 2.350382, 'id': 'melanie.dulong-de-rosnay@iscc.cnrs.fr'}
# ----------------
#
# MAIL NOT IN NAME DICT:  celine.barthonnat@revues.org
# _________________
# revues.org
# lat/lng  43.949162   4.8282792
# ________________
# STARTSTART2
# 'datetime.datetime' object has no attribute 'lower'
# {'end': '2018-03-02T15:19:10', 'name': 'celine.barthonnat@revues.org', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 43.949162, 'lng': 4.8282792, 'id': 'celine.barthonnat@revues.org'}
# ----------------
#
# mail luisyepez13@gmail.com
# start 2012-01-26T16:42:01
# end 2012-01-26T16:42:01
# name luis torres yepez
# gmail.com
# lat/lng  48.5139138897   -27.0818994565
# ________________
# mail wanono@ivry.cnrs.fr
# start 2012-01-26T13:31:45
# end 2012-01-26T13:31:45
# name nadine wanono
# ivry.cnrs.fr
# lat/lng  48.8176621   2.3710573
# ________________
# 1615
# <<<<<<<<<<<COUNT NODES>>>>>>>>>>>>> 772
# <<<<<<COUNT NODES NOT IN DICT>>>>>> 908
# <<<<<<<<<TOTAL>>>>>>> 1680
# 1615
# []

# %%
print len(my_nodesdict)
# Out:
# 1615

# %%
print  my_nodesdict
# Out:
# {'jwettla@gwdg.de': {'data': {'end': '2012-12-08T11:15:11', 'name': 'joerg wettlaufer', 'weight': 4.0, 'start': '2012-12-07T11:15:11', 'lat': 51.5632005, 'lng': 9.971094899999999, 'id': 'jwettla@gwdg.de'}}, 'vincent.puig@centrepompidou.fr': {'data': {'end': '2018-03-02T15:19:10', 'name': 'vincent.puig@centrepompidou.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.860642, 'lng': 2.352245, 'id': 'vincent.puig@centrepompidou.fr'}}, 'eda-liste@eric.univ-lyon2.fr': {'data': {'end': '2018-03-02T15:19:10', 'name': 'eda-liste@eric.univ-lyon2.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'eda-liste@eric.univ-lyon2.fr'}}, 'sophie.annoepel-cabrignac@inha.fr': {'data': {'end': '2018-03-02T15:19:10', 'name': 'sophie.annoepel-cabrignac@inha.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.86633639999999, 'lng': 2.3388561, 'id': 'sophie.annoepel-cabrignac@inha.fr'}}, 'eglantine.schmitt@utc.fr': {'data': {'end': '2015-06-03T22:30:25', 'name': 'eglantine schmitt', 'weight': 4.0, 'start': '2015-06-02T22:30:25', 'lat': 49.4152242, 'lng': 2.8191144, 'id': 'eglantine.schmitt@utc.fr'}}, 'stephanie.dordcrousle@ens-lyon.fr': {'data': {'end': '2018-03-02T15:19:10', 'name': 'stephanie.dordcrousle@ens-lyon.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 45.7298448, 'lng': 4.8285332, 'id': 'stephanie.dordcrousle@ens-lyon.fr'}}, 'pierre.vernus@ish-lyon.cnrs.fr': {'data': {'end': '2014-05-08T11:26:09', 'name': 'pierre vernus', 'weight': 4.0, 'start': '2014-05-07T11:26:09', 'lat': 45.74707309999999, 'lng': 4.835543599999999, 'id': 'pierre.vernus@ish-lyon.cnrs.fr'}}, 'richard.figuier@efrome.it': {'data': {'end': '2018-03-02T15:19:10', 'name': 'richard.figuier@efrome.it', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 41.8999458, 'lng': 12.4733322, 'id': 'richard.figuier@efrome.it'}}, 'alexandre.serres@uhb.fr': {'data': {'end': '2018-03-02T15:19:10', 'name': 'alexandre.serres@uhb.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.1179154, 'lng': -1.7028658, 'id': 'alexandre.serres@uhb.fr'}}, 'burghart@ehess.fr': {'data': {'end': '2013-04-28T17:13:26', 'name': 'burghart@ehess.fr', 'weight': 4.0, 'start': '2013-04-27T17:13:26', 'lat': 48.850174, 'lng': 2.3268487, 'id': 'burghart@ehess.fr'}}, 'laure.leveille@college-de-france.fr': {'data': {'end': '2018-03-02T15:19:10', 'name': 'laure.leveille@college-de-france.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8488839, 'lng': 2.3454896, 'id': 'laure.leveille@college-de-france.fr'}}, 'marie.planchot@paris-sorbonne.fr': {'data': {'end': '2018-03-02T15:19:10', 'name': 'marie.planchot@paris-sorbonne.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.8484556, 'lng': 2.3432774, 'id': 'marie.planchot@paris-sorbonne.fr'}}, 'helene.desmasures@culture.org': {'data': {'end': '2018-03-02T15:19:10', 'name': 'helene.desmasures@culture.org', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 33.6172584, 'lng': -111.9050735, 'id': 'helene.desmasures@culture.org'}}, 'aurelien.berra@orange.fr': {'data': {'end': '2018-03-02T15:19:10', 'name': 'aurelien.berra@orange.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'aurelien.berra@orange.fr'}}, 'delphine.montoliu@huma-num.fr': {'data': {'end': '2017-10-06T17:04:31', 'name': 'delphine montoliu', 'weight': 4.0, 'start': '2017-10-05T17:04:31', 'lat': 48.850142, 'lng': 2.3269827, 'id': 'delphine.montoliu@huma-num.fr'}}, 'fil-tmd@groupes.renater.fr': {'data': {'end': '2018-03-02T15:19:10', 'name': 'fil-tmd@groupes.renater.fr', 'weight': 4.0, 'start': '2012-03-02T15:19:10', 'lat': 48.51391388966784, 'lng': -27.08189945653708, 'id': 'fil-tmd@groupes.renater.fr'}}, 'bernard.hours@univ-lyon3.fr': {'data': {'end': '2013-03-27T21:30:57', 'name': 'hours bernard', 'weight': 4.0, 'start': '2013-03-20T19:46:43', 'lat': 45.748149, 'lng': 4.860552999999999, 'id': 'bernard.hours@univ-lyon3.fr'}} ...

# %%
from slugify import slugify


import random
import sys

def my_edges_list_singled() :
    my_edges=[]
    extra_nodes_non_autor_list=[]
    #print  corpus_mails_DH["./DHFRsample/2017-06/msg00011.html"]
    for mail in corpus_mails_DH:
        #print mail
        #print  corpus_mails_DH[mail]
        #if corpus_mails_DH[mail]["Geo_Topic"]["geo"][0] >=2 :
         #   print corpus_mails_DH[mail]["Geo_Topic"]["geo"][1]
            #print corpus_mails_DH[mail]["Geo_Topic"]["content"]
                
                
        if "liste_CCs" in corpus_mails_DH[mail]:
            for maild in corpus_mails_DH[mail]["liste_CCs"] :
                        if maild not in dict_noms_mails_debut_fin:
                            if maild not in extra_nodes_non_autor_list:
                                #print "OHOH NO, NO maild in liste_mail", maild
                                extra_nodes_non_autor_list.append(maild)
                                #print corpus_mails_DH[mail]["sujet_du_message"]

                        
                        if "sujet_du_message" in corpus_mails_DH[mail]:
                            
                            if corpus_mails_DH[mail]["Geo_Topic"]["geo"][0] >=3 :
                             
                                edge = {
                        "id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"])+" "+corpus_mails_DH[mail]["mail_auteur"]+maild+str(float(random.random())),
                        "source" : corpus_mails_DH[mail]["mail_auteur"].lower(),
                        "target" : maild.lower(),
                        "weight" : float(3),
                        "notes" : unicode(corpus_mails_DH[mail]["sujet_du_message"])+"\n KEYWORDS:"+str(corpus_mails_DH[mail]["Geo_Topic"]["geo"][1])+"\n"+slugify((corpus_mails_DH[mail]["Geo_Topic"]["content"]).decode("utf-8")),
                        "start": corpus_mails_DH[mail]["date"].strftime(DATETIME_FORMAT),
                        "color": "#3de866"
                                }
                            else:
                                edge = {
                        "id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"])+" "+corpus_mails_DH[mail]["mail_auteur"]+maild+str(float(random.random())),
                        "source" : corpus_mails_DH[mail]["mail_auteur"].lower(),
                        "target" : maild.lower(),
                        "weight" : float(1),
                        "notes" : unicode(corpus_mails_DH[mail]["sujet_du_message"]),
                        "start": corpus_mails_DH[mail]["date"].strftime(DATETIME_FORMAT),
                        "color": "#f5c0ae"
                        
                    }
                        else:
                            if corpus_mails_DH[mail]["Geo_Topic"]["geo"][0] >=3 :
                                edge = {
                        "id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"])+" "+corpus_mails_DH[mail]["mail_auteur"]+maild+str(float(random.random())),
                        "source" : corpus_mails_DH[mail]["mail_auteur"].lower(),
                        "target" : maild.lower(),
                        "weight" : float(3),
                        "start": corpus_mails_DH[mail]["date"].strftime(DATETIME_FORMAT),
                        "notes" : unicode("\n KEYWORDS:"+str(corpus_mails_DH[mail]["Geo_Topic"]["geo"][1])+"\n"+str(corpus_mails_DH[mail]["Geo_Topic"]["content"])),
                        "color": "#3de866"
                            }
                            else:
                                edge = {
                        "id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"])+" "+corpus_mails_DH[mail]["mail_auteur"]+maild+str(float(random.random())),
                        "source" : corpus_mails_DH[mail]["mail_auteur"].lower(),
                        "target" : maild.lower(),
                        "weight" : float(1),
                        "start": corpus_mails_DH[mail]["date"].strftime(DATETIME_FORMAT),
                        "color":"#fbe4dc"
                        
                            }
                        
                        
                       
                    
                            
                        my_edges.append({ "data" : edge })

        for maild in corpus_mails_DH[mail]["liste_mails_dests"] :
                        if maild not in dict_noms_mails_debut_fin:
                                if maild not in extra_nodes_non_autor_list:
                                    #print "OHOH NO, NO maild in liste_mail", maild
                                    extra_nodes_non_autor_list.append(maild)
            
                        if "sujet_du_message" in corpus_mails_DH[mail]:
                            
                            if corpus_mails_DH[mail]["Geo_Topic"]["geo"][0] >=2 :
                             
                                edge = {
                        "id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"])+" "+corpus_mails_DH[mail]["mail_auteur"]+maild+str(float(random.random())),
                        "source" : corpus_mails_DH[mail]["mail_auteur"].lower(),
                        "target" : maild.lower(),
                        "weight" : float(7),
                        "notes" : unicode(corpus_mails_DH[mail]["sujet_du_message"])+"\n KEYWORDS:"+str(corpus_mails_DH[mail]["Geo_Topic"]["geo"][1])+"\n"+slugify((corpus_mails_DH[mail]["Geo_Topic"]["content"]).decode("utf-8")),
                        "start": corpus_mails_DH[mail]["date"].strftime(DATETIME_FORMAT),
                        "color": "#3de866"
                                }
                            else:
                                #print corpus_mails_DH[mail]["date"]
                                #print corpus_mails_DH[mail]["date"].strftime(DATETIME_FORMAT)
                                edge = {
                        "id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"])+" "+corpus_mails_DH[mail]["mail_auteur"]+maild+str(float(random.random())),
                        "source" : corpus_mails_DH[mail]["mail_auteur"].lower(),
                        "target" : maild.lower(),
                        "weight" : float(4),
                        "notes" : unicode(corpus_mails_DH[mail]["sujet_du_message"]),
                        "start": corpus_mails_DH[mail]["date"].strftime(DATETIME_FORMAT),
                        "color": "#f5c0ae"
                        
                    }
                        else:
                            if corpus_mails_DH[mail]["Geo_Topic"]["geo"][0] >=2 :
                                edge = {
                        "id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"])+" "+corpus_mails_DH[mail]["mail_auteur"]+maild+str(float(random.random())),
                        "source" : corpus_mails_DH[mail]["mail_auteur"].lower(),
                        "target" : maild.lower(),
                        "weight" : float(7),
                        "start": corpus_mails_DH[mail]["date"].strftime(DATETIME_FORMAT),
                        "notes" : unicode("\n KEYWORDS:"+str(corpus_mails_DH[mail]["Geo_Topic"]["geo"][1])+"\n"+str(corpus_mails_DH[mail]["Geo_Topic"]["content"])),
                        "color": "#3de866"
                            }
                            else:
                                edge = {
                        "id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"])+" "+corpus_mails_DH[mail]["mail_auteur"]+maild+str(float(random.random())),
                        "source" : corpus_mails_DH[mail]["mail_auteur"].lower(),
                        "target" : maild.lower(),
                        "weight" : float(4),
                        "start": corpus_mails_DH[mail]["date"].strftime(DATETIME_FORMAT),
                        "color":"#fbe4dc"
                        
                            }
            
                        my_edges.append({ "data" : edge })



    #print len(my_edges)
    #print extra_nodes_non_autor_list
    #print len(extra_nodes_non_autor_list)
    return [my_edges,extra_nodes_non_autor_list]

my_edges_singled=my_edges_list_singled()[0]
extra_nodes=my_edges_list_singled()[1]

# %%
#print extra_nodes


for mail in extra_nodes:
    
        print mail
        
#        start= mail_array[1]
#        end= mail_array[2]
        mail_address_suffix=mail.split("@",1)[1]
        print mail_address_suffix
        if mail_address_suffix in dict_corrected_DH  :
            
            lat=dict_corrected_DH[mail_address_suffix]["geometry"]["location"]["lat"]
            lng=dict_corrected_DH[mail_address_suffix]["geometry"]["location"]["lng"]
            node = {
                        "id" : mail,
                        "name" : mail,
                       "lat" : float(lat),
                       "lng" : float(lng),
                       "weight" : float(4),

                        }
        else: 
            
        
            node = {
                        "id" : mail,
                        "name" : mail,
                       "weight" : float(4),
                        
                        }
        
            print node
        my_nodes.append({ "data" : node })   
        my_nodesdict[node["id"]]= { "data" : node }
    
print len(my_nodesdict)
# Out:
# dh@groupes.renater.fr
# groupes.renater.fr
# dh@cru.fr
# cru.fr
# marin.dacos@revues.org
# revues.org
# monique.peyriere@gmail.com
# gmail.com
# humanum-veille@listes.huma-num.fr
# listes.huma-num.fr
# humanum-diffusion@listes.huma-num.fr
# listes.huma-num.fr
# header.from=singrid.chene@enc.sorbonne.fr
# enc.sorbonne.fr
# educasup.philo@ml.free.fr
# ml.free.fr
# culture.numerique@ml.free.fr
# ml.free.fr
# legram@yahoogroupes.fr
# yahoogroupes.fr
# listesocius@groups.openedition.org
# groups.openedition.org
# ln@cines.fr
# cines.fr
# corpus-ecrits@cru.fr
# cru.fr
# cahier@groupes.renater.fr
# groupes.renater.fr
# jkrybicki@gmail.com
# gmail.com
# pierre.mounier@gmail.com
# gmail.com
# marin.dacos@openedition.org
# gregory.grefenstette@inria.fr
# inria.fr
# melanie.dulong-de-rosnay@iscc.cnrs.fr
# iscc.cnrs.fr
# dontchuengkouam@yahoo.fr
# yahoo.fr
# rtmedias@yahoogroupes.fr
# yahoogroupes.fr
# vincent.lariviere@umontreal.ca
# umontreal.ca
# marc@microfiches.org
# microfiches.org
# semaineoa2017@framalistes.org
# framalistes.org
# ebsi-l@listes.umontreal.ca
# listes.umontreal.ca
# christiane.aubin@umontreal.ca
# umontreal.ca
# nathalie.beaufay@umontreal.ca
# umontreal.ca
# bureau-rozec.emmanuelle@uqam.ca
# uqam.ca
# figura@concordia.ca
# concordia.ca
# salondouble@contemporain.info
# contemporain.info
# catherine.bernier@umontreal.ca
# umontreal.ca
# arielle.tordjman@umontreal.ca
# umontreal.ca
# alice.lubrano.lavadera@gmail.com
# gmail.com
# swiss-lib@switch.ch
# switch.ch
# daniela.vaj@unil.ch
# unil.ch
# dino.buzzetti@gmail.com
# gmail.com
# list-egc@polytech.univ-nantes.fr
# polytech.univ-nantes.fr
# philippe.basciano@orange.fr
# orange.fr
# francesca.tomasi@unibo.it
# unibo.it
# clarisse_bardiot@mac.com
# mac.com
# exploreat@oeaw.ac.at
# oeaw.ac.at
# florence.clavaud@enc.sorbonne.fr
# enc.sorbonne.fr
# orbital@cines.fr
# cines.fr
# ahn@ens-lyon.fr
# ens-lyon.fr
# thierry.daunois@univ-lorraine.fr
# univ-lorraine.fr
# guillaume.goa@gmail.com
# gmail.com
# laurence.rosier@ulb.ac.be
# ulb.ac.be
# nicolasrichardv@gmail.com
# gmail.com
# christine.berthou-ballot@brest-metropole.fr
# brest-metropole.fr
# michele.hubert-veron@brest-metropole.fr
# brest-metropole.fr
# xavier.laubie@intradef.gouv.fr
# intradef.gouv.fr
# jy.besselievre@musee-marine.fr
# musee-marine.fr
# querrec@enib.fr
# enib.fr
# serge.garlatti@telecom-bretagne.eu
# telecom-bretagne.eu
# cecile.favre@univ-lyon2.fr
# univ-lyon2.fr
# pascale.kuntz@univ-nantes.fr
# univ-nantes.fr
# emmanuelle.morlock-gerstenkorn@ish-lyon.cnrs.fr
# ish-lyon.cnrs.fr
# digit_hum@ens.fr
# ens.fr
# svhoolan@ulb.ac.be
# ulb.ac.be
# ruben.verborgh@ugent.be
# ugent.be
# dh@tr
# tr
# documentation@cfpci.fr
# cfpci.fr
# sebastien.francois@rocketmail.com
# rocketmail.com
# elise.gruselle@inha.fr
# inha.fr
# richard.walter@cnrs-orleans.fr
# cnrs-orleans.fr
# celine.barthonnat@openedition.org
# openedition.org
# prodev@services.cnrs.fr
# services.cnrs.fr
# open-education@lists.okfn.org
# lists.okfn.org
# linkedup-public@l3s.de
# l3s.de
# alexandre.guilbaud@imj-prg.fr
# imj-prg.fr
# drupaladmin@mail.h-net.msu.edu
# mail.h-net.msu.edu
# jakob.epler@dariah.eu
# dariah.eu
# 1615

# %%
my_edges=my_edges_singled
print len(my_edges)
print my_edges[:100]
# Out:
# 7320
# [{'data': {'target': 'dh@groupes.renater.fr', 'weight': 4.0, 'start': '
 'id': u'../DHFR/groupes.renater.fr/sympa/arc/dh/2015-06/msg00037.html isabelle.jouve@ysalide.comdh@groupes.renater.fr0.494579932519'}}, {'data': {'target': 'dh@cru.fr', 'weight': 1.0, 'start': '2011-07-18T11:01:00', 'color': '#f5c0ae', 'notes': u": re: [dh] consultation de l'union europ\xe9enne su r le num\xe9rique", 'source': 'marionlame@gmail.com', 'id': u'../DHFR/groupes.renater.fr/sympa/arc/dh/2011-07/msg00002.html marionlame@gmail.comdh@cru.fr0.734148941311'}}, {'data': {'target': 'marin.dacos@revues.org', 'weight': 4.0, 'start': '2011-07-18T11:01:00', 'color': '#f5c0ae', 'notes': u": re: [dh] consultation de l'union europ\xe9enne su r le num\xe9rique", 'source': 'marionlame@gmail.com', 'id': u'../DHFR/groupes.renater.fr/sympa/ar ...

# %%
def my_edges_list_by_source_dest() :
    my_edges=[]

    for mail in corpus_mails_DH:
        #print mail
         #print  corpus_mails_DH[mail]
        if "liste_CCs" in corpus_mails_DH[mail]:
            for maild in corpus_mails_DH[mail]["liste_CCs"] :
                #print unicode(corpus_mails_DH[mail]["sujet_du_message"])
                edge = {
                    #"id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                    "source" : corpus_mails_DH[mail]["mail_auteur"],
                    "target" : maild,
                    "weight" : float(2),
                    #"name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])+" "+
                }
                my_edges.append({ "data" : edge })

        for maild in corpus_mails_DH[mail]["liste_mails_dests"] :
            edge = {
                #"id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                "source" : corpus_mails_DH[mail]["mail_auteur"],
                "target" : maild,
                "weight" : float(5),
                #"name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])
            }
            my_edges.append({ "data" : edge })



    print len(my_edges)
    return my_edges

my_edges_duped=my_edges_list_by_source_dest()
# Out:
# 526

# %%
def my_edges_list_with_subject() :
    my_edges=[]

    for mail in corpus_mails_DH:
        #print mail
         #print  corpus_mails_DH[mail]
        if "liste_CCs" in corpus_mails_DH[mail]:
            for maild in corpus_mails_DH[mail]["liste_CCs"] :
                #print unicode(corpus_mails_DH[mail]["sujet_du_message"])
                edge = {
                    #"id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                    "source" : corpus_mails_DH[mail]["mail_auteur"],
                    "target" : maild,
                    #"weight" : float(2),
                    "name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])
                }
                my_edges.append({ "data" : edge })

        for maild in corpus_mails_DH[mail]["liste_mails_dests"] :
            edge = {
                #"id":unicode(corpus_mails_DH[mail]["ref_physique_de_l_article"]),
                "source" : corpus_mails_DH[mail]["mail_auteur"],
                "target" : maild,
                #"weight" : float(5),
                "name" : unicode(corpus_mails_DH[mail]["sujet_du_message"])
            }
            my_edges.append({ "data" : edge })



    print len(my_edges)

    return my_edges

my_edges_duped_with_subject=my_edges_list_with_subject()

# %%
#WE HAVE TO TEST THE EDGES, BUT IT IS AN ARRAY OF DICTS,SO WE NEED TO FLATTEN THEM TO COUNT THEM SIMPLY

import collections

def flatten(d, parent_key='', sep='_'):
    items = []
    for k, v in d.items():
        new_key = parent_key + sep + k if parent_key else k
        if isinstance(v, collections.MutableMapping):
            items.extend(flatten(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# %%
def list_flattener_and_finder(edges_list_singled,edges_list_duped):
    from collections import Counter
    import ast
    my_edges_replacement_deduped=[]
    receiver=[]
    for i,dic in enumerate(edges_list_duped):
        #print my_edges[i]
        dicto=flatten(edges_list_duped[i])
    #    print dicto
        receiver.append(str(dicto))

    #print receiver
    CREE= Counter(receiver).iteritems()
    total=0
    dups=0
    dups_cnt=0
    
    print edges_list_singled[:1]
    for key, value in CREE:
        #print key
        #print value
        keyB={'data':{}}
        total+=1
        
        #print ast.literal_eval(key)["data_source"]
        #print ast.literal_eval(key)["data_target"]        
        keyB={'data':{"source":ast.literal_eval(key)["data_source"],"target": ast.literal_eval(key)["data_target"]}}
        #print "SUP",key, value
        dups+=value
        dups_cnt+=1
        #print ">>",keyB
        #print ast.literal_eval(key)["data_weight"]    
        keyB["data"]["weight"]= float(value*float(ast.literal_eval(key)["data_weight"]))
        #print "KEYB____",keyB
        my_edges_replacement_deduped.append(keyB)


            





    print "total",total

    print "dups",dups
    print "dups_cnt",dups_cnt
    return my_edges_replacement_deduped

listor=list_flattener_and_finder(my_edges,my_edges_duped)
print listor

# %%
res=dups/dups_cnt

# %%
my_edges=listor

# %%
# connect to the topogram instance (pass debug=True params for more info )
topogram = TopogramAPIClient(TOPOGRAM_URL) #, debug=True)

# create a new user
try :
    topogram.create_user(USER, PASSWORD)
except ValueError:
    print "> User has already been created."

# login a new user if needed
resp_user_login = topogram.user_login(USER, PASSWORD)
print resp_user_login

assert(resp_user_login["status"] == "success")
assert(resp_user_login["status_code"] == 200)
my_nodesdictList = []
for key, value in my_nodesdict.iteritems():
    
    my_nodesdictList.append(value)
# Out:
# ERROR:topogram-client:403 Unauthorized request
# > User has already been created.
# {u'status': u'success', 'status_code': 200, u'data': {u'authToken': u'9kilE8biG7Ae-8RyoZA35-I_WCe3ZjQAFTz3hTzpWN9', u'userId': u'BxRn4kp4WFL92jW8g'}}

# %%
#print my_edges
list_nodes_id=[] 
for nodes in  my_nodesdictList:
    if nodes['data']['id'] not in list_nodes_id:
        list_nodes_id.append(nodes['data']['id'])
    
print len(list_nodes_id)

print list_nodes_id
for edge in my_edges:
    source= edge['data']['source']
    target= edge['data']['target']
    if source not in list_nodes_id:
        print "NO!"
        print source
    if target not in list_nodes_id:
        print "NO2!"
        print target
# Out:
# 0
# []

# %%
TOPOGRAM_URL = "http://localhost:3000"

# %%
TOPOGRAM_URL = "https://app.topogram.io"

# %%
title = "betaDH3singlevizOK"
create_topogram(title, my_nodesdictList, my_edges)
# Out:
# ERROR:topogram-client:500 - Error : A topogram with the same name already exists
# Creating topogram 'betaDH3singlevizOK'
# > Topogram already exists
# {u'status': u'success', 'status_code': 200, u'data': {u'sharedPublic': False, u'title': u'betaDH3singlevizOK', u'userId': u'BxRn4kp4WFL92jW8g', u'_id': u'yytNBHwTn6Eeif4pC', u'slug': u'betadh3singlevizok', u'createdAt': u'2018-05-02T13:59:11.445Z'}, u'statusCode': 200}
# topogram ID : yytNBHwTn6Eeif4pC
# {u'status': u'success', 'status_code': 200, u'data': [u'L7bZHr4qSwhhgAeAd', u'99b8BHpkDqf4d97DY', u'6HhMqoBBnxJjG4rhS', u'YMkBtJLpXftdhTtK2', u'j6bDqB8FhhiJzCcLj', u'kyHHFX6ztC5emPjJm', u'NGSRwYuNzdRqJ7JNd', u'krasMWBfNByxd3xmM', u'WrLdfbJya69vswtKT', u'EL5zEJ4hBysMhfWxn', u'F4znFxXLmmcCAspqY', u'PbCPEBcwfLScuEzEt', u'28mShntXEpJTtpsSG', u'y4QCBJr8SSgqS4GwT', u'doW8mix2C2Ai2785h', u'4Hjo9mqo26BzzF65o', u'MiNJofW9zuDETgsKi', u'ZjLRd5xzsHNbYxh88', u'phehSkHcZZK4AM9An', u'BFi2odQmKqF8qjbT2', u'AGSSYuvo2Qg3g9aK5', u'8vfcfxq2dB62kxgzr', u'fGpwvMRRggvWZipJd', u'DgNPuKanRYb99uzX8', u'GzcxAmjnmFyd8MBda', u'zX5ymFhowtJEhtPLs', u'mLThbWDAhA55AHNRe', u'Y5Mqp2XZLReeKt2gr', u'YrETLykswkyv47kA6', u'7s3azsSHmg9fBFe28', u'EvCTNFu2csEnExZMq', u'mFPnYK64o6KZYHfRJ', u'qG6czyKnAQbv49